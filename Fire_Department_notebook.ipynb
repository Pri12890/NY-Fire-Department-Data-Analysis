# %% [markdown]
# # ANALYSIS OF NEWYORK FIRE DEPARTMENT DATA

# %% [markdown]
# ### The NewYork City Fire Department keeps a log of detailed information on incidents handled by FDNY units. This dataset contains around 1 million rows. We will work on this dataset that contains a record of incidents handled by FDNY units from 2013-2017.

# %%
import pandas as pd


# Read the Fire Department Data
fire_data = pd.read_csv('~/Desktop/Fire_Dept.csv')
#fire_data.head()
type(fire_data)
len(fire_data)
# Out:
# 1048575

# %%
# number of rows in Fire Department Data 
len(fire_data)
# Out:
# 1048575

# %%
fire_data.tail(505)
# Out:
#          IM_INCIDENT_KEY FIRE_BOX  \
# 1048070         58490137      933
# 1048071         58490142      396
# 1048072         58490143      123
# 1048073         58490146      137
# 1048074         58490147      759
# 1048075         58490149     1624
# 1048076         58490151     4443
# 1048077         58490156     1157
# 1048078         58490158     1690
# 1048079         58490162     2938
# 1048080         58490163     7408
# 1048081         58490195     2532
# 1048082         58490203     9687
# 1048083         58490206     1391
# 1048084         58490211      854
# 1048085         58490215     7899
# 1048086         58490216      272
# 1048087         58490217      170
# 1048088         58490218     9678
# 1048089         58490219     1182
# 1048090         58490222     1349
# 1048091         58490223     1009
# 1048092         58490225     4426
# 1048093         58490231     3592
# 1048094         58490237     2519
# 1048095         58490238     1072
# ...

# %% [markdown]
# ### What proportion of FDNY responses correspond to the most common type of incident

# %%
# What proportion of FDNY responses correspond to the most common type of incident 

# Find the number of unique incidents in the fire_data 
fire_data.INCIDENT_TYPE_DESC.value_counts()

# With this
# The output shows that 300 was the most common type of incident 
# Ans - hence 375694/1048575 is the proportion  = 0.3582 = 35.82%
# Out:
# 300 - Rescue, EMS incident, other                               375694
# 651 - Smoke scare, odor of smoke                                 67021
# 522 - Water or steam leak                                        56381
# 710 - Malicious, mischievous false call, other                   55252
# 353 - Removal of victim(s) from stalled elevator                 52552
# 412 - Gas leak (natural gas or LPG)                              45933
# 735A - Unwarranted alarm/defective condition of alarm system     43453
# 113 - Cooking fire, confined to container                        41049
# 736 - CO detector activation due to malfunction                  21767
# 555 - Defective elevator, no occupants                           20324
# 322 - Motor vehicle accident with injuries                       20231
# 445 - Arcing, shorted electrical equipment                       17994
# 740A - Unnecessary alarm/construction activities                 14996
# ...

# %% [markdown]
# ### What is the ratio of average number of units that arrive to a scene of an incident classified as "111- Building Fire" to the no that arrive for "651 - Smoke scare- odor of smoke"

# %%
# #fire_data.
# fire_data.head()
# # create variable with TRUE if building fire 
# building_fire = fire_data['INCIDENT_TYPE_DESC'] == "111- Building Fire"
# building_fire.head()
# # Create variable with TRUE if units_onscene >= 0
# units_onscene = fire_data['UNITS_ONSCENE'] >=0 
# # select cases with building fire and units_onscene >=0 (to avoid missing values)
# fire_data[building_fire & units_onscene]

building_fire = fire_data.loc[fire_data['INCIDENT_TYPE_DESC'] == "111 - Building fire" ]
#building_fire
smoke_scare = fire_data.loc[fire_data['INCIDENT_TYPE_DESC'] == "651 - Smoke scare, odor of smoke"]
#smoke_scare
fire_units_mean = building_fire['UNITS_ONSCENE'].mean()
#fire_units_mean
smoke_units_mean = smoke_scare['UNITS_ONSCENE'].mean()
#smoke_units_mean
ratio = fire_units_mean/smoke_units_mean
ratio # Ans 
#building_fire
# Out:
# 90        2013-01-01 01:00:00
# 198       2013-01-01 02:25:00
# 439       2013-01-01 06:26:00
# 491       2013-01-01 08:03:00
# 568       2013-01-01 09:49:00
# 615       2013-01-01 11:11:00
# 749       2013-01-01 13:57:00
# 947       2013-01-01 17:38:00
# 1040      2013-01-01 19:18:00
# 1049      2013-01-01 19:28:00
# 1056      2013-01-01 19:35:00
# 1280      2013-01-02 01:11:00
# 1454      2013-01-02 08:32:00
# 1484      2013-01-02 08:52:00
# 1543      2013-01-02 10:08:00
# 1607      2013-01-02 11:15:00
# 1747      2013-01-02 14:01:00
# 1795      2013-01-02 14:47:00
# 1928      2013-01-02 16:37:00
# 1992      2013-01-02 17:35:00
# 2018      2013-01-02 18:10:00
# 2203      2013-01-02 21:25:00
# 2388      2013-01-03 03:48:00
# 2555      2013-01-03 09:44:00
# 2562      2013-01-03 09:49:00
# 2897      2013-01-03 15:25:00
# 2898      2013-01-03 15:30:00
# 3295      2013-01-03 21:49:00
# 3451      2013-01-04 03:11:00
# 3485      2013-01-04 05:33:00
#                   ...
# ...

# %% [markdown]
# ### How many times more likely is an incident in Staten Island a false call compared to in Manhattan? The answer should be the ratio of Staten Island false call rate to Manhattan False Call Rate. A False call is an incident for which "INCIDENT TYPE DESC" is "710 - Malicious, mischievous, false call, other

# %%
# Incidents in Staten Island False Call 
#False_Staten 
#fire_data.head(50)
staten = fire_data.loc[fire_data['BOROUGH_DESC'] == '3 - Staten Island'] #and ['INCIDENT_TYPE_DESC'] == '710 - Malicious, mischievous false call, other']
#and ['INCIDENT_TYPE_DESC' == '710 - Malicious, mischievous false call, other']]
staten.head()
len(staten)
false_staten = staten.loc[staten['INCIDENT_TYPE_DESC'] == '710 - Malicious, mischievous false call, other']
len(false_staten)
#False_Manhattan 
manhattan = fire_data.loc[fire_data['BOROUGH_DESC'] == '1 - Manhattan']
manhattan.head()
false_manhattan = manhattan.loc[manhattan['INCIDENT_TYPE_DESC'] == '710 - Malicious, mischievous false call, other']
len(false_manhattan), len(false_staten)
ratio = len(false_staten)/len(false_manhattan)
ratio
d.head()
# for dd in d:
#     if(dd == )
#     print(type(dd))
    #if (dd == )

# %% [markdown]
# ### We can use FDNY Dataset to investigate at what time of the day people cook most.

# %%
#Compute what proportion of all incidents are cooking fires for every hour of the day by 
#normalizing the number of cooking fires in a given hour by the total number of cooking fires 
#that occured in that hour. Find the hour of the day that has the highest proportion of cooking 
#fires and submit that proportion of cooking fires. A cooking fire is an incident for 
#which "INCIDENT TYPE DESC" is "113 - Cooking Fire, confined to container. 
#Note - Round Incident times down. For example - if an incident occured at 22:55, it occured in hour 22. 


cooking_fire = fire_data.loc[fire_data['INCIDENT_TYPE_DESC'] == "113 - Cooking fire, confined to container"]
len(cooking_fire)
cooking_fire.head()
fire_data.head(100)
cooking_fire['INCIDENT_DATE'], cooking_fire['INCIDENT_TIME'] = zip(*cooking_fire['INCIDENT_DATE_TIME'].map(lambda x: x.split(' ')))
cooking_fire['INCIDENT_HOUR'], cooking_fire['INCIDENT_MINS'] = zip(*cooking_fire['INCIDENT_TIME'].map(lambda x: x.split(':')))
cooking_fire.head()
hour_max_val = cooking_fire['INCIDENT_HOUR'].value_counts()[0]
# SO THE TIME OF DAY PEOPLE COOK MOST IS 18TH HOUR I.E. 6PM 
prop_cf_18 = hour_max_val/len(cooking_fire)
prop_cf_18
fire_data
# Out:
# /Users/priyankaagrawal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/priyankaagrawal/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#          IM_INCIDENT_KEY FIRE_BOX  \
# 0               55672688     2147
# 1               55672692      818
# 2               55672693     9656
# 3               55672695     7412
# 4               55672697     4019
# ...

# %% [markdown]
# ### Check the distribution of the number of minutes it takes between the time a "111- Building Fire" incident has been logged into the computer Aided Dispatch System and the time at which the first unit arrives on scene. What is the third quartile of that distribution. Note - the number of minutes can be fractional (i.e. do not round)

# %%
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt 

building_fire = building_fire.loc[building_fire['INCIDENT_TYPE_DESC'] == "111 - Building fire"]
incident_time=pd.to_datetime(building_fire['INCIDENT_DATE_TIME'])
arrival_time = pd.to_datetime(building_fire['ARRIVAL_DATE_TIME'])
diff_time = arrival_time - incident_time
diff_time.head()
len(building_fire)
counter=Counter(diff_time)
counter
#len(counter)
#diff_time
# for a in diff_time: 
#     if(a=='+23:55:00'):
#         print(building_fire['incident_time'])
###TODO
# Out:
# Counter({Timedelta('0 days 00:02:00'): 898,
#          Timedelta('0 days 00:03:00'): 2468,
#          Timedelta('0 days 00:06:00'): 260,
#          Timedelta('0 days 00:04:00'): 2182,
#          Timedelta('0 days 00:01:00'): 113,
#          Timedelta('0 days 00:05:00'): 827,
#          Timedelta('0 days 00:07:00'): 83,
#          Timedelta('0 days 00:09:00'): 12,
#          NaT: 9,
#          Timedelta('0 days 00:08:00'): 15,
#          Timedelta('0 days 00:11:00'): 2,
#          Timedelta('0 days 00:13:00'): 2,
#          Timedelta('0 days 00:00:00'): 20,
#          Timedelta('0 days 00:10:00'): 6,
#          Timedelta('0 days 00:16:00'): 1,
#          Timedelta('0 days 00:14:00'): 1,
#          Timedelta('0 days 00:12:00'): 1,
#          Timedelta('0 days 00:15:00'): 2,
#          Timedelta('0 days 00:17:00'): 1,
#          Timedelta('-1 days +23:55:00'): 1,
#          Timedelta('0 days 00:43:00'): 1})

# %% [markdown]
# ### What is the coefficient of determination (R squared) between the number of residents at each zip code and the number of incidents whose type is classified as "111 - Building Fire" at each of those zip codes. Note - The 2010 US Census Population by zip code dataset should be downloaded. Use both FDNY responses and the US Census dataset. Ignore zip codes that do not appear in the census table.

# %%
fire_data.head()
# 2010 US census Population by zip code dataset not available.
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692      818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other        1/1/13 0:00
# 1  735A - Unwarranted alarm/defective condition o...        1/1/13 0:00
# 2                  300 - Rescue, EMS incident, other        1/1/13 0:01
# 3                412 - Gas leak (natural gas or LPG)        1/1/13 0:02
# 4  735A - Unwarranted alarm/defective condition o...        1/1/13 0:01
#
#   ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0       1/1/13 0:14            1.0                 1/1/13 0:20
# 1       1/1/13 0:09            3.0                 1/1/13 0:30
# 2       1/1/13 0:04            1.0                 1/1/13 0:15
# 3       1/1/13 0:07            4.0                 1/1/13 0:40
# ...

# %% [markdown]
# ## CO Detector Analysis
# ### For this analysis, only consider incidents that have information about whether a CO detector was present or not. We are interested in how many times more likely it is that an incident is long when no CO detector is present compared to when a CO Detector is present. For events with CO Detector and those without one, compute the proportion of incidents that lasted 20-30, 30-40, 40-50, 50-60 and 60-70 minutes (both interval boundary values included) by dividing the no of incidents in each time interval with the total number of incidents. For each bin, compute the ratio of "CO Detector absent" frequency to the "CO Detector present" frequency. Perform a linear regression of this ratio to the mid-point of the bins. From this, what is the predicted ratio for events lasting 39 minutes?

# %%
# CO Detector Analysis 

co_detector = fire_data.loc[fire_data['CO_DETECTOR_PRESENT_DESC'].notnull()]
len(co_detector)



co_det_yes = co_detector.loc[co_detector['CO_DETECTOR_PRESENT_DESC']== "Yes"]
len(co_det_yes)
co_det_no = co_detector.loc[co_detector['CO_DETECTOR_PRESENT_DESC']== "No"]
len(co_det_no)
# co-detector absent ratio
# a = co_det_no[(co_det_no.TOTAL_INCIDENT_DURATION >= 20) & (co_det_no.TOTAL_INCIDENT_DURATION <= 30)].count()

#df[(df.a >= 1) & (df.a < 3)].count()
# CALCULATIONS FOR 20-30 MINUTES WINDOW 
# co_det_no
ratio_2030_con_coy = 0 
c1n=co_det_no.loc[(co_det_no['TOTAL_INCIDENT_DURATION'] >= 20) & (co_det_no['TOTAL_INCIDENT_DURATION'] <= 30)]
c1_no = len(c1n)
c1y = co_det_yes.loc[(co_det_yes['TOTAL_INCIDENT_DURATION'] >= 20) & (co_det_yes['TOTAL_INCIDENT_DURATION'] <= 30)]
c1_yes = len(c1y)
if c1_yes == 0:
    print("cant divide by zero")
else: 
    ratio_2030_con_coy = c1_no/c1_yes  
    print("ratio_20-30 = ", ratio_2030_con_coy)
print(c1_no)
print(c1_yes)
#print(ratio_2030_con_coy)

# CALCULATIONS FOR 30-40 MINUTES WINDOW 
ratio_3040_con_coy = 0 
c1n=co_det_no.loc[(co_det_no['TOTAL_INCIDENT_DURATION'] >= 30) & (co_det_no['TOTAL_INCIDENT_DURATION'] <= 40)]
c1_no = len(c1n)
c1y = co_det_yes.loc[(co_det_yes['TOTAL_INCIDENT_DURATION'] >= 30) & (co_det_yes['TOTAL_INCIDENT_DURATION'] <= 40)]
c1_yes = len(c1y)
if c1_yes == 0:
    print("cant divide by zero")
else: 
    ratio_3040_con_coy = c1_no/c1_yes  
    print("ratio_30-40 = ", ratio_3040_con_coy)
print(c1_no)
print(c1_yes)
#print(ratio_2030_con_coy)

# CALCULATIONS FOR 40-50 MINUTES WINDOW 
ratio_4050_con_coy = 0 
c1n=co_det_no.loc[(co_det_no['TOTAL_INCIDENT_DURATION'] >= 40) & (co_det_no['TOTAL_INCIDENT_DURATION'] <= 50)]
c1_no = len(c1n)
c1y = co_det_yes.loc[(co_det_yes['TOTAL_INCIDENT_DURATION'] >= 40) & (co_det_yes['TOTAL_INCIDENT_DURATION'] <= 50)]
c1_yes = len(c1y)
if c1_yes == 0:
    print("cant divide by zero")
else: 
    ratio_4050_con_coy = c1_no/c1_yes  
    print("ratio_40-50 = ", ratio_4050_con_coy)
print(c1_no)
print(c1_yes)
#print(ratio_2030_con_coy)

# Similarly find all
# Out:
# cant divide by zero
# 0
# 0
# ratio_30-40 =  0.25
# 1
# 4
# ratio_40-50 =  0.42857142857142855
# 3
# 7

# %% [markdown]
# ### Calculate the chi-square test statistic for testing whether an incident is more likely to last longer than 60 minutes when CO Detector is not present. Again, only consider incidents that have information about whether a CO Detector was present or not.

# %%
df = pd.DataFrame({'a': [1, 2, 3]})

# %%
df
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
# df[df.a > 1].count()
df = pd.DataFrame({"class":[1,1,1,2,2], "value":[1,2,3,4,5]})
df
# Out:
#    class  value
# 0      1      1
# 1      1      2
# 2      1      3
# 3      2      4
# 4      2      5

# %%
(df[(df.class >= 1) & (df.class < 3)]).count()
# Out:
#   File "<ipython-input-368-996c904a34a4>", line 1
#     (df[(df.class >= 1) & (df.class < 3)]).count()
#                 ^
# SyntaxError: invalid syntax

# %%
#co_det_no.loc[(co_det_no['TOTAL_INCIDENT_DURATION'] >= 20) & (co_det_no['TOTAL_INCIDENT_DURATION'] <= 30)].count()
fff=co_det_no.loc[(co_det_no['TOTAL_INCIDENT_DURATION'] >= 20) & (co_det_no['TOTAL_INCIDENT_DURATION'] <= 30) ]
#type(fff)
len(fff)
#len(co_det_no)
# Out:
# 0
